# %%
# !pip install -U sec-edgar-downloader
# !pip install openai
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: sec-edgar-downloader in ./.venv/lib/python3.9/site-packages (5.0.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.9/site-packages (from sec-edgar-downloader) (2.31.0)
# Requirement already satisfied: pyrate-limiter>=3.1.0 in ./.venv/lib/python3.9/site-packages (from sec-edgar-downloader) (3.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests->sec-edgar-downloader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests->sec-edgar-downloader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests->sec-edgar-downloader) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests->sec-edgar-downloader) (2024.2.2)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in ./.venv/lib/python3.9/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.9/site-packages (from openai) (4.66.4)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.9/site-packages (from openai) (3.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.20->openai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests>=2.20->openai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests>=2.20->openai) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests>=2.20->openai) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp->openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp->openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->openai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in ./.venv/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.9/site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.9/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (1.26.4)

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in ./.venv/lib/python3.9/site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in ./.venv/lib/python3.9/site-packages (from flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in ./.venv/lib/python3.9/site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in ./.venv/lib/python3.9/site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in ./.venv/lib/python3.9/site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in ./.venv/lib/python3.9/site-packages (from flask) (1.8.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in ./.venv/lib/python3.9/site-packages (from flask) (7.1.0)
# Requirement already satisfied: zipp>=0.5 in ./.venv/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->flask) (3.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from Jinja2>=3.1.2->flask) (2.1.5)

# %%
import os
import glob
import openai
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
import re
import shutil

openai.api_key = 'API_KEY_HERE'
# Out:
# /Users/adi_shukla/Documents/sec-edgar-proj/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from sec_edgar_downloader import Downloader

# %%
dl = Downloader("ShuklaInc", "adityashukla2015@gmail.com")
print(dl.get("10-K", "MSFT", after="1994-12-31", before="2024-01-01"))
print(dl.get("10-K", "TSLA", after="1994-12-31", before="2024-01-01"))
print(dl.get("10-K", "AAPL", after="1994-12-31", before="2024-01-01"))
# Out:
# 29
# 13
# 27

# %%
def analyze_company(company_folder, year_folder):
    """
    Analyzes the 10-K filings of a company for a given year by extracting financial insights using OpenAI's GPT model.

    Parameters:
    - company_folder (str): Path to the folder containing the company's 10-K filings.
    - year_folder (str): The specific year folder to analyze within the company's 10-K filings.

    Returns:
    - tuple: A tuple containing the company name, year, and a dictionary of extracted financial insights.
    """
    # Read all submission.txt files in the year_folder
    report_text = ""
    year_folder_path = os.path.join(company_folder, year_folder)
    for submission_folder in os.listdir(year_folder_path):
        submission_folder_path = os.path.join(year_folder_path, submission_folder)
        if os.path.isdir(submission_folder_path):
            submission_file_path = os.path.join(submission_folder_path, 'submission.txt')
            if os.path.exists(submission_file_path):
                with open(submission_file_path, 'r') as file:
                    submission_text = file.read()
                    report_text += submission_text + "\n"
                    print(f"Read report from: {submission_file_path}\n{submission_text}")  # Debug statement

    company_name = os.path.basename(os.path.dirname(company_folder))

    # JSON extraction prompt
    json_prompt = f"""
    From the 10-k filing information that is passed in to you, extract the following information: Revenue (product wise if applicable), Net Income (product wise if applicable), Effective Tax Rate, Deferred Tax Assets, Deferred Tax Liabilities, Foreign Income Percentage, and any other relevant financial information.
    Answer in proper json format. Make sure the format is right that it doesn't face the JSONDecodeError: Expecting ',' delimiter issue. Note: Only return the json, no additional text.
    Example Json (sub-fields may not match completely and change but the units should be same (billions), convert if you need to)
    {{
        "2022": {{
            "Revenue": {{"Compute & Networking": "$26.938 billion", "Graphics": "$11.718 billion"}},
            "Net Income": {{"Compute & Networking": "$7.634 billion", "Graphics": "$2.462 billion"}},
            "Effective Tax Rate": "9.9%",
            "Deferred Tax Assets": "$5.05 billion",
            "Deferred Tax Liabilities": "$339 million",
            "Foreign Income Percentage": "85%"
        }},
        "2021": {{
            ...
        }}
    }}

    Note: main fields ("Revenue", "Net Income", "Effective Tax Rate", "Deferred Tax Assets", "Deferred Tax Liabilities", "Foreign Income Percentage") should be present in the json. However, sub-fields may vary for example for Revenue the source of revenue may be different for different companies or different for same company in different years. You should mention the source of revenue in the sub-fields.
    Also mention profit or loss with positive or negative sign in front of the number.
    Make sure the json format is parseable and correct and doesn't face issues like "Expecting property name enclosed in double quotes", "Expecting ',' delimiter", etc.
    Here are the reports:
    {report_text}
    """

    try:
        response_json = openai.Completion.create(
            model="gpt-3.5-turbo-instruct",
            prompt=json_prompt,
            max_tokens=1500,
            n=1,
            stop=None,
            temperature=0.7,
        )
        json_data = response_json['choices'][0]['text'].strip()
        print(f"Extracted JSON data for {company_name} - {year_folder}: {json_data}")  # Debug statement
        json_insights = json.loads(json_data)
    except Exception as e:
        print(f"Error extracting JSON insights for {company_name} - {year_folder}: {e}")  # Debug statement
        print(f"json_data: {json_data}")  # Debug statement
        json_insights = {}

    return company_name, year_folder, json_insights

def save_insights_to_json(company_name, year_folder, insights):
    """
    Saves the extracted financial insights to a JSON file.

    Parameters:
    - company_name (str): Name of the company.
    - year_folder (str): The year of the financial insights.
    - insights (dict): A dictionary containing the extracted financial insights.
    """
    os.makedirs('insights', exist_ok=True)
    company_folder = os.path.join('insights', company_name)
    os.makedirs(company_folder, exist_ok=True)
    insights_path = os.path.join(company_folder, f"{year_folder}_insights.json")
    with open(insights_path, 'w') as insights_file:
        json.dump(insights, insights_file)
    print(f"Saved insights for {company_name} - {year_folder} to {insights_path}")

base_folder = '/Users/adi_shukla/Documents/sec-edgar-proj/sec-edgar-filings'
companies = ['AAPL', 'MSFT', 'TSLA']

for company in companies:
    company_folder = os.path.join(base_folder, company, '10-K')
    year_folders = sorted(os.listdir(company_folder), reverse=True)  # Sort folders in descending order
    for year_folder in year_folders:
        if os.path.isdir(os.path.join(company_folder, year_folder)):
            company_name, year, insights = analyze_company(company_folder, year_folder)
            save_insights_to_json(company_name, year, insights)

print("Completed processing all companies.")
# Out:
# Extracted JSON data for AAPL - 0001628280-16-020309: {
#     "2022": {
#         "Revenue": {
#             "Total": "$25.93 billion",
#             "Compute & Networking": "$26.938 billion",
#             "Graphics": "$11.718 billion",
#             "Storage": "$5.926 billion",
#             "Enterprise, Embedded and Semi-Custom": "$3.087 billion",
#             "Other": "$2.462 billion"
#         },
#         "Net Income": {
#             "Total": "$10.634 billion",
#             "Compute & Networking": "$7.634 billion",
#             "Graphics": "$2.462 billion",
#             "Storage": "$0.926 billion",
#             "Enterprise, Embedded and Semi-Custom": "$0.087 billion",
#             "Other": "$0.134 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Total": "$23.93 billion",
#             "Compute & Networking": "$24.938 billion",
#             "Graphics": "$10.718 billion",
#             "Storage": "$4.926 billion",
#             "Enterprise, Embedded and Semi-Custom": "$2.087 billion",
#             "Other": "$1.462 billion"
#         },
#         "Net Income": {
#             "Total": "$8.634 billion",
#             "Compute & Networking": "$6.634 billion",
#             "Graphics": "$1.462 billion",
#             "Storage": "$0.926 billion",
#             "Enterprise, Embedded and Semi-Custom": "$0.087 billion",
#             "Other": "$0.134 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$3.05 billion",
#         "Deferred Tax Liabilities": "$239 million",
#         "Foreign Income Percentage": "85%"
#     }
# }
# Saved insights for AAPL - 0001628280-16-020309 to insights/AAPL/0001628280-16-020309_insights.json
# Extracted JSON data for AAPL - 0001193125-15-356351: {
#     "2022": {
#         "Revenue": {
#             "Compute & Networking": "$26.938 billion",
#             "Graphics": "$11.718 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$7.634 billion",
#             "Graphics": "$2.462 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Compute & Networking": "$24.654 billion",
#             "Graphics": "$10.215 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$6.825 billion",
#             "Graphics": "$1.972 billion"
#         },
#         "Effective Tax Rate": "10.2%",
#         "Deferred Tax Assets": "$4.32 billion",
#         "Deferred Tax Liabilities": "$301 million",
#         "Foreign Income Percentage": "82%"
#     }
# }
# Saved insights for AAPL - 0001193125-15-356351 to insights/AAPL/0001193125-15-356351_insights.json
# Extracted JSON data for AAPL - 0001193125-14-383437: {
#     "2020": {
#         "Revenue": {"Product A": "$10 billion", "Product B": "$15 billion"},
#         "Net Income": {"Product A": "$2 billion", "Product B": "$3 billion"},
#         "Effective Tax Rate": "20%",
#         "Deferred Tax Assets": "$1 billion",
#         "Deferred Tax Liabilities": "$500 million",
#         "Foreign Income Percentage": "60%"
#     },
#     "2019": {
#         "Revenue": {"Product A": "$9 billion", "Product B": "$12 billion"},
#         "Net Income": {"Product A": "$1 billion", "Product B": "$2 billion"},
#         "Effective Tax Rate": "18%",
#         "Deferred Tax Assets": "$750 million",
#         "Deferred Tax Liabilities": "$400 million",
#         "Foreign Income Percentage": "55%"
#     },
#     "2018": {
#         "Revenue": {"Product A": "$8 billion", "Product B": "$10 billion"},
#         "Net Income": {"Product A": "$500 million", "Product B": "$1 billion"},
#         "Effective Tax Rate": "15%",
#         "Deferred Tax Assets": "$500 million",
#         "Deferred Tax Liabilities": "$300 million",
#         "Foreign Income Percentage": "50%"
#     }
# }
# Saved insights for AAPL - 0001193125-14-383437 to insights/AAPL/0001193125-14-383437_insights.json
# Extracted JSON data for AAPL - 0001193125-13-416534: {
#     "2022": {
#         "Revenue": {
#             "Compute & Networking": "Positive $26.938 billion",
#             "Graphics": "Positive $11.718 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "Positive $7.634 billion",
#             "Graphics": "Positive $2.462 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "Positive $5.05 billion",
#         "Deferred Tax Liabilities": "Positive $339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Compute & Networking": "Positive $24.677 billion",
#             "Graphics": "Positive $9.714 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "Positive $6.957 billion",
#             "Graphics": "Positive $1.704 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "Positive $5.238 billion",
#         "Deferred Tax Liabilities": "Positive $309 million",
#         "Foreign Income Percentage": "85%"
#     }
# }
# Saved insights for AAPL - 0001193125-13-416534 to insights/AAPL/0001193125-13-416534_insights.json
# Extracted JSON data for AAPL - 0001193125-12-444068: {
#     "2021": {
#         "Revenue": {
#             "Product A": "$2.1 billion",
#             "Product B": "$3.5 billion",
#             "Product C": "$5.2 billion"
#         },
#         "Net Income": {
#             "Product A": "$0.1 billion",
#             "Product B": "$0.5 billion",
#             "Product C": "$-0.2 billion"
#         },
#         "Effective Tax Rate": "18.9%",
#         "Deferred Tax Assets": "$1.5 billion",
#         "Deferred Tax Liabilities": "$0.1 billion",
#         "Foreign Income Percentage": "75%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product A": "$1.7 billion",
#             "Product B": "$2.8 billion",
#             "Product C": "$4.5 billion"
#         },
#         "Net Income": {
#             "Product A": "$0.2 billion",
#             "Product B": "$0.4 billion",
#             "Product C": "$-0.1 billion"
#         },
#         "Effective Tax Rate": "19.1%",
#         "Deferred Tax Assets": "$1.2 billion",
#         "Deferred Tax Liabilities": "$0.1 billion",
#         "Foreign Income Percentage": "70%"
#     }
# }
# Saved insights for AAPL - 0001193125-12-444068 to insights/AAPL/0001193125-12-444068_insights.json
# Extracted JSON data for AAPL - 0001193125-11-282113: We cannot generate a JSON string without the input data.
# Error extracting JSON insights for AAPL - 0001193125-11-282113: Expecting value: line 1 column 1 (char 0)
# json_data: We cannot generate a JSON string without the input data.
# Saved insights for AAPL - 0001193125-11-282113 to insights/AAPL/0001193125-11-282113_insights.json
# Extracted JSON data for AAPL - 0001193125-10-238044: {
#     "2019": {
#         "Revenue": {
#             "Product 1": "$100 million",
#             "Product 2": "$200 million"
#         },
#         "Net Income": {
#             "Product 1": "$50 million",
#             "Product 2": "$25 million"
#         },
#         "Effective Tax Rate": "20%",
#         "Deferred Tax Assets": "$10 million",
#         "Deferred Tax Liabilities": "$5 million",
#         "Foreign Income Percentage": "70%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product 1": "$150 million",
#             "Product 2": "$300 million"
#         },
#         "Net Income": {
#             "Product 1": "$75 million",
#             "Product 2": "$50 million"
#         },
#         "Effective Tax Rate": "15%",
#         "Deferred Tax Assets": "$15 million",
#         "Deferred Tax Liabilities": "$10 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for AAPL - 0001193125-10-238044 to insights/AAPL/0001193125-10-238044_insights.json
# Extracted JSON data for AAPL - 0001193125-09-214859: {
#     "2021": {
#         "Revenue": {
#             "Product 1": {
#                 "Source": "Source A",
#                 "Amount": "$10 billion"
#             },
#             "Product 2": {
#                 "Source": "Source B",
#                 "Amount": "$5 billion"
#             }
#         },
#         "Net Income": {
#             "Product 1": {
#                 "Source": "Source A",
#                 "Amount": "$2 billion",
#                 "Profit or Loss": "$2 billion"
#             },
#             "Product 2": {
#                 "Source": "Source B",
#                 "Amount": "$4 billion",
#                 "Profit or Loss": "$4 billion"
#             }
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$1 billion",
#         "Deferred Tax Liabilities": "$500 million",
#         "Foreign Income Percentage": "80%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product 1": {
#                 "Source": "Source A",
#                 "Amount": "$8 billion"
#             },
#             "Product 2": {
#                 "Source": "Source B",
#                 "Amount": "$6 billion"
#             }
#         },
#         "Net Income": {
#             "Product 1": {
#                 "Source": "Source A",
#                 "Amount": "$1 billion",
#                 "Profit or Loss": "-$1 billion"
#             },
#             "Product 2": {
#                 "Source": "Source B",
#                 "Amount": "$3 billion",
#                 "Profit or Loss": "$3 billion"
#             }
#         },
#         "Effective Tax Rate": "8%",
#         "Deferred Tax Assets": "$800 million",
#         "Deferred Tax Liabilities": "$200 million",
#         "Foreign Income Percentage": "75%"
#     }
# }
# Saved insights for AAPL - 0001193125-09-214859 to insights/AAPL/0001193125-09-214859_insights.json
# Extracted JSON data for AAPL - 0001193125-08-224958:
# Error extracting JSON insights for AAPL - 0001193125-08-224958: Expecting value: line 1 column 1 (char 0)
# json_data:
# Saved insights for AAPL - 0001193125-08-224958 to insights/AAPL/0001193125-08-224958_insights.json
# Extracted JSON data for AAPL - 0001104659-06-084288: {"2020":
# {"Revenue":
# {"Product 1": "$9.33 billion",
# "Product 2": "$2.26 billion"},
# "Net Income":
# {"Product 1": "$1.36 billion",
# "Product 2": "$0.50 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"},
# "2019":
# {"Revenue":
# {"Product 1": "$8.29 billion",
# "Product 2": "$2.13 billion"},
# "Net Income":
# {"Product 1": "$1.10 billion",
# "Product 2": "$0.36 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"}}
#
# {"2020":
# {"Revenue":
# {"Product 1": "$9.33 billion",
# "Product 2": "$2.26 billion"},
# "Net Income":
# {"Product 1": "$1.36 billion",
# "Product 2": "$0.50 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"},
# "2019":
# {"Revenue":
# {"Product 1": "$8.29 billion",
# "Product 2": "$2.13 billion"},
# "Net Income":
# {"Product 1": "$1.10 billion",
# "Product 2": "$0.36 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"}}
# Error extracting JSON insights for AAPL - 0001104659-06-084288: Extra data: line 24 column 1 (char 641)
# json_data: {"2020":
# {"Revenue":
# {"Product 1": "$9.33 billion",
# "Product 2": "$2.26 billion"},
# "Net Income":
# {"Product 1": "$1.36 billion",
# "Product 2": "$0.50 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"},
# "2019":
# {"Revenue":
# {"Product 1": "$8.29 billion",
# "Product 2": "$2.13 billion"},
# "Net Income":
# {"Product 1": "$1.10 billion",
# "Product 2": "$0.36 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"}}
#
# {"2020":
# {"Revenue":
# {"Product 1": "$9.33 billion",
# "Product 2": "$2.26 billion"},
# "Net Income":
# {"Product 1": "$1.36 billion",
# "Product 2": "$0.50 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"},
# "2019":
# {"Revenue":
# {"Product 1": "$8.29 billion",
# "Product 2": "$2.13 billion"},
# "Net Income":
# {"Product 1": "$1.10 billion",
# "Product 2": "$0.36 billion"},
# "Effective Tax Rate": "9.9%",
# "Deferred Tax Assets": "$5.05 billion",
# "Deferred Tax Liabilities": "$339 million",
# "Foreign Income Percentage": "85%"}}
# Saved insights for AAPL - 0001104659-06-084288 to insights/AAPL/0001104659-06-084288_insights.json
# Extracted JSON data for AAPL - 0001104659-05-058421: {
#     "2021": {
#         "Revenue": {
#             "Product A": "$10 billion",
#             "Product B": "$5 billion"
#         },
#         "Net Income": {
#             "Product A": "-$2 billion",
#             "Product B": "$1 billion"
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$1 billion",
#         "Deferred Tax Liabilities": "$500 million",
#         "Foreign Income Percentage": "70%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product A": "$8 billion",
#             "Product B": "$3 billion"
#         },
#         "Net Income": {
#             "Product A": "$1 billion",
#             "Product B": "-$500 million"
#         },
#         "Effective Tax Rate": "12%",
#         "Deferred Tax Assets": "$500 million",
#         "Deferred Tax Liabilities": "$200 million",
#         "Foreign Income Percentage": "65%"
#     }
# }
# Saved insights for AAPL - 0001104659-05-058421 to insights/AAPL/0001104659-05-058421_insights.json
# Extracted JSON data for AAPL - 0001047469-97-006960: {
#   "2021": {
#     "Revenue": {
#       "Total Revenue": "$274.515 billion",
#       "Product Revenue": "$274.515 billion",
#       "Service Revenue": "$0.0 billion"
#     },
#     "Net Income": {
#       "Total Net Income": "$90.027 billion",
#       "Product Net Income": "$90.027 billion",
#       "Service Net Income": "$0.0 billion"
#     },
#     "Effective Tax Rate": "16.9%",
#     "Deferred Tax Assets": "$28.243 billion",
#     "Deferred Tax Liabilities": "$0.0 billion",
#     "Foreign Income Percentage": "60%"
#   },
#   "2020": {
#     "Revenue": {
#       "Total Revenue": "$274.515 billion",
#       "Product Revenue": "$274.515 billion",
#       "Service Revenue": "$0.0 billion"
#     },
#     "Net Income": {
#       "Total Net Income": "$90.027 billion",
#       "Product Net Income": "$90.027 billion",
#       "Service Net Income": "$0.0 billion"
#     },
#     "Effective Tax Rate": "16.9%",
#     "Deferred Tax Assets": "$28.243 billion",
#     "Deferred Tax Liabilities": "$0.0 billion",
#     "Foreign Income Percentage": "60%"
#   }
# }
# Saved insights for AAPL - 0001047469-97-006960 to insights/AAPL/0001047469-97-006960_insights.json
# Extracted JSON data for AAPL - 0001047469-07-009340: {
#     "2021": {
#         "Revenue": {
#             "Product A": "$100 million",
#             "Product B": "$50 million"
#         },
#         "Net Income": {
#             "Product A": "$10 million",
#             "Product B": "$5 million"
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$1 million",
#         "Deferred Tax Liabilities": "$500,000",
#         "Foreign Income Percentage": "80%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product A": "$90 million",
#             "Product B": "$40 million"
#         },
#         "Net Income": {
#             "Product A": "$9 million",
#             "Product B": "$4 million"
#         },
#         "Effective Tax Rate": "9%",
#         "Deferred Tax Assets": "$500,000",
#         "Deferred Tax Liabilities": "$300,000",
#         "Foreign Income Percentage": "75%"
#     }
# }
# Saved insights for AAPL - 0001047469-07-009340 to insights/AAPL/0001047469-07-009340_insights.json
# Extracted JSON data for AAPL - 0001047469-04-035975: {
#     "2019": {
#         "Revenue": {
#             "Product A": "$10.5 billion",
#             "Product B": "$5.8 billion"
#         },
#         "Net Income": {
#             "Product A": "$1.2 billion",
#             "Product B": "$0.8 billion"
#         },
#         "Effective Tax Rate": "25%",
#         "Deferred Tax Assets": "$2.5 billion",
#         "Deferred Tax Liabilities": "$1.2 billion",
#         "Foreign Income Percentage": "75%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product A": "$12.3 billion",
#             "Product B": "$6.5 billion"
#         },
#         "Net Income": {
#             "Product A": "$1.5 billion",
#             "Product B": "$0.9 billion"
#         },
#         "Effective Tax Rate": "23%",
#         "Deferred Tax Assets": "$2.8 billion",
#         "Deferred Tax Liabilities": "$1.5 billion",
#         "Foreign Income Percentage": "80%"
#     },
#     "2021": {
#         "Revenue": {
#             "Product A": "$15.2 billion",
#             "Product B": "$8.3 billion"
#         },
#         "Net Income": {
#             "Product A": "$1.8 billion",
#             "Product B": "$1.2 billion"
#         },
#         "Effective Tax Rate": "21%",
#         "Deferred Tax Assets": "$3.2 billion",
#         "Deferred Tax Liabilities": "$1.8 billion",
#         "Foreign Income Percentage": "85%"
#     },
#     "2022": {
#         "Revenue": {
#             "Product A": "$18.5 billion",
#             "Product B": "$10.2 billion"
#         },
#         "Net Income": {
#             "Product A": "$2.1 billion",
#             "Product B": "$1.5 billion"
#         },
#         "Effective Tax Rate": "18%",
#         "Deferred Tax Assets": "$3.8 billion",
#         "Deferred Tax Liabilities": "$2.1 billion",
#         "Foreign Income Percentage": "90%"
#     }
# }
# Saved insights for AAPL - 0001047469-04-035975 to insights/AAPL/0001047469-04-035975_insights.json
# Extracted JSON data for AAPL - 0001047469-03-041604: {
#     "2021": {
#         "Revenue": {
#             "2021 Total Revenue": "$274.515 billion",
#             "2021 Sales": "$191.743 billion",
#             "2021 Services": "$82.772 billion"
#         },
#         "Net Income": {
#             "2021 Net Income": "$63.953 billion",
#             "2021 Net Income per Share": "$24.76"
#         },
#         "Effective Tax Rate": "14.5%",
#         "Deferred Tax Assets": "$9.061 billion",
#         "Deferred Tax Liabilities": "$1.235 billion",
#         "Foreign Income Percentage": "72%"
#     },
#     "2020": {
#         "Revenue": {
#             "2020 Total Revenue": "$273.857 billion",
#             "2020 Sales": "$191.542 billion",
#             "2020 Services": "$82.315 billion"
#         },
#         "Net Income": {
#             "2020 Net Income": "$57.411 billion",
#             "2020 Net Income per Share": "$22.52"
#         },
#         "Effective Tax Rate": "14.4%",
#         "Deferred Tax Assets": "$8.562 billion",
#         "Deferred Tax Liabilities": "$1.078 billion",
#         "Foreign Income Percentage": "74%"
#     },
#     "2019": {
#         "Revenue": {
#             "2019 Total Revenue": "$260.174 billion",
#             "2019 Sales": "$180.677 billion",
#             "2019 Services": "$79.497 billion"
#         },
#         "Net Income": {
#             "2019 Net Income": "$55.256 billion",
#             "2019 Net Income per Share": "$21.41"
#         },
#         "Effective Tax Rate": "11.3%",
#         "Deferred Tax Assets": "$6.782 billion",
#         "Deferred Tax Liabilities": "$1.298 billion",
#         "Foreign Income Percentage": "71%"
#     },
#     "2018": {
#         "Revenue": {
#             "2018 Total Revenue": "$265.595 billion",
#             "2018 Sales": "$178.819 billion",
#             "2018 Services": "$86.776 billion"
#         },
#         "Net Income": {
#             "2018 Net Income": "$59.531 billion",
#             "2018 Net Income per Share": "$22.43"
#         },
#         "Effective Tax Rate": "9.6%",
#         "Deferred Tax Assets": "$5.962 billion",
#         "Deferred Tax Liabilities": "$1.222 billion",
#         "Foreign Income Percentage": "71%"
#     },
#     "2017": {
#         "Revenue": {
#             "2017 Total Revenue": "$229.234 billion",
#             "2017 Sales": "$157.701 billion",
#             "2017 Services": "$71.533 billion"
#         },
#         "Net Income": {
#             "2017 Net Income": "$48.351 billion",
#             "2017 Net Income per Share": "$18.02"
#         },
#         "Effective Tax Rate": "11.5%",
#         "Deferred Tax Assets": "$5.527 billion",
#         "Deferred Tax Liabilities": "$1.151 billion",
#         "Foreign Income Percentage": "66%"
#     },
#     "2016": {
#         "Revenue": {
#             "2016 Total Revenue": "$215.639 billion",
#             "2016 Sales": "$149.589 billion",
#             "2016 Services": "$66.05 billion"
#         },
#         "Net Income": {
#             "2016 Net Income": "$37.732 billion",
#             "2016 Net Income per Share": "$14.13"
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$5.175 billion",
#         "Deferred Tax Liabilities": "$1.042 billion",
#         "Foreign Income Percentage": "65%"
#     }
# }
# Saved insights for AAPL - 0001047469-03-041604 to insights/AAPL/0001047469-03-041604_insights.json
# Extracted JSON data for AAPL - 0001047469-02-007674: {
#     "2021":{
#         "Revenue":{
#             "Total Revenue":"$274.515 billion",
#             "Product-wise Revenue":{
#                 "Compute & Networking":"$26.938 billion",
#                 "Graphics":"$11.718 billion",
#                 "Enterprise, Embedded and Semi-Custom":"$235.859 billion"
#             }
#         },
#         "Net Income":{
#             "Total Net Income":"$45.061 billion",
#             "Product-wise Net Income":{
#                 "Compute & Networking":"$7.634 billion",
#                 "Graphics":"$2.462 billion",
#                 "Enterprise, Embedded and Semi-Custom":"$35.965 billion"
#             }
#         },
#         "Effective Tax Rate":"9.9%",
#         "Deferred Tax Assets":"$5.05 billion",
#         "Deferred Tax Liabilities":"$339 million",
#         "Foreign Income Percentage":"85%"
#     },
#     "2020":{
#         "Revenue":{
#             "Total Revenue":"$233.715 billion",
#             "Product-wise Revenue":{
#                 "Compute & Networking":"$24.374 billion",
#                 "Graphics":"$9.714 billion",
#                 "Enterprise, Embedded and Semi-Custom":"$199.627 billion"
#             }
#         },
#         "Net Income":{
#             "Total Net Income":"$45.501 billion",
#             "Product-wise Net Income":{
#                 "Compute & Networking":"$6.731 billion",
#                 "Graphics":"$2.386 billion",
#                 "Enterprise, Embedded and Semi-Custom":"$36.384 billion"
#             }
#         },
#         "Effective Tax Rate":"10.5%",
#         "Deferred Tax Assets":"$4.291 billion",
#         "Deferred Tax Liabilities":"$301 million",
#         "Foreign Income Percentage":"83%"
#     }
# }
# Saved insights for AAPL - 0001047469-02-007674 to insights/AAPL/0001047469-02-007674_insights.json
# Extracted JSON data for AAPL - 0000912057-99-010244: {
#         "2020": {
#             "Revenue": {
#                 "Product A": "$3.8 billion",
#                 "Product B": "$1.5 billion",
#                 "Product C": "$1.7 billion"
#             },
#             "Net Income": {
#                 "Product A": "$2.7 billion",
#                 "Product B": "$1.1 billion",
#                 "Product C": "-$0.2 billion"
#             },
#             "Effective Tax Rate": "17%",
#             "Deferred Tax Assets": "$2.4 billion",
#             "Deferred Tax Liabilities": "$1.6 billion",
#             "Foreign Income Percentage": "75%"
#         },
#         "2019": {
#             "Revenue": {
#                 "Product A": "$3.2 billion",
#                 "Product B": "$1.2 billion",
#                 "Product C": "$1.4 billion"
#             },
#             "Net Income": {
#                 "Product A": "$2.3 billion",
#                 "Product B": "$1.0 billion",
#                 "Product C": "$0.1 billion"
#             },
#             "Effective Tax Rate": "18%",
#             "Deferred Tax Assets": "$2.0 billion",
#             "Deferred Tax Liabilities": "$1.2 billion",
#             "Foreign Income Percentage": "80%"
#         }
#     }
# Saved insights for AAPL - 0000912057-99-010244 to insights/AAPL/0000912057-99-010244_insights.json
# Extracted JSON data for AAPL - 0000912057-00-053623: {
#     "2022": {
#         "Revenue": {
#             "Compute & Networking": "$26.938 billion",
#             "Graphics": "$11.718 billion",
#             "Other": "$10.123 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$7.634 billion",
#             "Graphics": "$2.462 billion",
#             "Other": "-$1.234 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Compute & Networking": "$25.683 billion",
#             "Graphics": "$10.625 billion",
#             "Other": "$8.765 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$6.789 billion",
#             "Graphics": "$2.123 billion",
#             "Other": "-$876 million"
#         },
#         "Effective Tax Rate": "10.5%",
#         "Deferred Tax Assets": "$4.56 billion",
#         "Deferred Tax Liabilities": "$289 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for AAPL - 0000912057-00-053623 to insights/AAPL/0000912057-00-053623_insights.json
# Extracted JSON data for AAPL - 0000320193-96-000023: {
#     "2019": {
#         "Revenue": {
#             "Product": "$60.7 billion",
#             "Service": "$4.7 billion"
#         },
#         "Net Income": {
#             "Product": "$11.6 billion",
#             "Service": "$1.3 billion"
#         },
#         "Effective Tax Rate": "9.8%",
#         "Deferred Tax Assets": "$6.5 billion",
#         "Deferred Tax Liabilities": "$461 million",
#         "Foreign Income Percentage": "81%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product": "$69.9 billion",
#             "Service": "$6.7 billion"
#         },
#         "Net Income": {
#             "Product": "$13.8 billion",
#             "Service": "$1.6 billion"
#         },
#         "Effective Tax Rate": "10.4%",
#         "Deferred Tax Assets": "$7.2 billion",
#         "Deferred Tax Liabilities": "$489 million",
#         "Foreign Income Percentage": "83%"
#     },
#     "2021": {
#         "Revenue": {
#             "Product": "$78.1 billion",
#             "Service": "$8.1 billion"
#         },
#         "Net Income": {
#             "Product": "$16.9 billion",
#             "Service": "$2.1 billion"
#         },
#         "Effective Tax Rate": "11.2%",
#         "Deferred Tax Assets": "$8.5 billion",
#         "Deferred Tax Liabilities": "$532 million",
#         "Foreign Income Percentage": "84%"
#     },
#     "2022": {
#         "Revenue": {
#             "Product": "$86.3 billion",
#             "Service": "$9.6 billion"
#         },
#         "Net Income": {
#             "Product": "$19.7 billion",
#             "Service": "$2.6 billion"
#         },
#         "Effective Tax Rate": "11.9%",
#         "Deferred Tax Assets": "$9.8 billion",
#         "Deferred Tax Liabilities": "$567 million",
#         "Foreign Income Percentage": "85%"
#     }
# }
# Saved insights for AAPL - 0000320193-96-000023 to insights/AAPL/0000320193-96-000023_insights.json
# Extracted JSON data for AAPL - 0000320193-95-000016: {
#     "2021": {
#         "Revenue": {
#             "Compute & Networking": "$26.938 billion",
#             "Graphics": "$11.718 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$7.634 billion",
#             "Graphics": "$2.462 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2020": {
#         "Revenue": {
#             "Compute & Networking": "$26.937 billion",
#             "Graphics": "$11.717 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$7.635 billion",
#             "Graphics": "$2.463 billion"
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$5.06 billion",
#         "Deferred Tax Liabilities": "$340 million",
#         "Foreign Income Percentage": "86%"
#     }
# }
# Saved insights for AAPL - 0000320193-95-000016 to insights/AAPL/0000320193-95-000016_insights.json
# Extracted JSON data for AAPL - 0000320193-94-000016:
# Error extracting JSON insights for AAPL - 0000320193-94-000016: Expecting value: line 1 column 1 (char 0)
# json_data:
# Saved insights for AAPL - 0000320193-94-000016 to insights/AAPL/0000320193-94-000016_insights.json
# Extracted JSON data for AAPL - 0000320193-23-000106: {
#     "2021": {
#         "Revenue": {
#             "Product and Service Revenue": "$274.515 billion",
#             "Product Revenue": "$274.515 billion",
#             "Service Revenue": "$0 billion"
#         },
#         "Net Income": {
#             "Product and Service Revenue": "$59.319 billion",
#             "Product Revenue": "$59.319 billion",
#             "Service Revenue": "$0 billion"
#         },
#         "Effective Tax Rate": "8.9%",
#         "Deferred Tax Assets": "$8.307 billion",
#         "Deferred Tax Liabilities": "$5.248 billion",
#         "Foreign Income Percentage": "75.3%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product and Service Revenue": "$274.515 billion",
#             "Product Revenue": "$274.515 billion",
#             "Service Revenue": "$0 billion"
#         },
#         "Net Income": {
#             "Product and Service Revenue": "$86.778 billion",
#             "Product Revenue": "$86.778 billion",
#             "Service Revenue": "$0 billion"
#         },
#         "Effective Tax Rate": "9.1%",
#         "Deferred Tax Assets": "$7.942 billion",
#         "Deferred Tax Liabilities": "$4.497 billion",
#         "Foreign Income Percentage": "72.5%"
#     }
# }
# Saved insights for AAPL - 0000320193-23-000106 to insights/AAPL/0000320193-23-000106_insights.json
# Extracted JSON data for AAPL - 0000320193-22-000108: {
#         "2020": {
#             "Revenue": {
#                 "Compute & Networking": "$26.938 billion",
#                 "Graphics": "$11.718 billion"
#             },
#             "Net Income": {
#                 "Compute & Networking": "-$7.634 billion",
#                 "Graphics": "-$2.462 billion"
#             },
#             "Effective Tax Rate": "9.9%",
#             "Deferred Tax Assets": "$5.05 billion",
#             "Deferred Tax Liabilities": "$339 million",
#             "Foreign Income Percentage": "85%"
#         },
#         "2019": {
#             "Revenue": {
#                 "Compute & Networking": "$24.533 billion",
#                 "Graphics": "$10.614 billion"
#             },
#             "Net Income": {
#                 "Compute & Networking": "-$5.472 billion",
#                 "Graphics": "-$1.866 billion"
#             },
#             "Effective Tax Rate": "12.6%",
#             "Deferred Tax Assets": "$4.621 billion",
#             "Deferred Tax Liabilities": "$392 million",
#             "Foreign Income Percentage": "83%"
#         },
#         "2018": {
#             "Revenue": {
#                 "Compute & Networking": "$21.739 billion",
#                 "Graphics": "$9.734 billion"
#             },
#             "Net Income": {
#                 "Compute & Networking": "-$3.310 billion",
#                 "Graphics": "-$1.048 billion"
#             },
#             "Effective Tax Rate": "14.3%",
#             "Deferred Tax Assets": "$3.857 billion",
#             "Deferred Tax Liabilities": "$294 million",
#             "Foreign Income Percentage": "81%"
#         }
#     }
# Saved insights for AAPL - 0000320193-22-000108 to insights/AAPL/0000320193-22-000108_insights.json
# Extracted JSON data for AAPL - 0000320193-21-000105: 1) https://www.sec.gov/Archives/edgar/data/1318605/000131860521000015/nvda-20210131.htm
#     2) https://www.sec.gov/Archives/edgar/data/1318605/000131860521000015/nvda-20210131.htm
#
#     {"2021": {
#         "Revenue": {
#             "Gaming": "$8.049 billion",
#             "Professional Visualization": "$1.871 billion",
#             "Data Center": "$6.702 billion"
#         },
#         "Net Income": {
#             "Gaming": "$2.186 billion",
#             "Professional Visualization": "$0.442 billion",
#             "Data Center": "$2.009 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2020": {
#         "Revenue": {
#             "Gaming": "$6.467 billion",
#             "Professional Visualization": "$0.762 billion",
#             "Data Center": "$5.433 billion"
#         },
#         "Net Income": {
#             "Gaming": "$1.666 billion",
#             "Professional Visualization": "$0.224 billion",
#             "Data Center": "$1.649 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$4.192 billion",
#         "Deferred Tax Liabilities": "$152 million",
#         "Foreign Income Percentage": "87%"
#     }}
# Error extracting JSON insights for AAPL - 0000320193-21-000105: Extra data: line 1 column 2 (char 1)
# json_data: 1) https://www.sec.gov/Archives/edgar/data/1318605/000131860521000015/nvda-20210131.htm
#     2) https://www.sec.gov/Archives/edgar/data/1318605/000131860521000015/nvda-20210131.htm
#
#     {"2021": {
#         "Revenue": {
#             "Gaming": "$8.049 billion",
#             "Professional Visualization": "$1.871 billion",
#             "Data Center": "$6.702 billion"
#         },
#         "Net Income": {
#             "Gaming": "$2.186 billion",
#             "Professional Visualization": "$0.442 billion",
#             "Data Center": "$2.009 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2020": {
#         "Revenue": {
#             "Gaming": "$6.467 billion",
#             "Professional Visualization": "$0.762 billion",
#             "Data Center": "$5.433 billion"
#         },
#         "Net Income": {
#             "Gaming": "$1.666 billion",
#             "Professional Visualization": "$0.224 billion",
#             "Data Center": "$1.649 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$4.192 billion",
#         "Deferred Tax Liabilities": "$152 million",
#         "Foreign Income Percentage": "87%"
#     }}
# Saved insights for AAPL - 0000320193-21-000105 to insights/AAPL/0000320193-21-000105_insights.json
# Extracted JSON data for AAPL - 0000320193-20-000096: {
#     "2021": {
#         "Revenue": {
#             "Product A": "$25.65 billion",
#             "Product B": "$12.37 billion",
#             "Product C": "$8.45 billion"
#         },
#         "Net Income": {
#             "Product A": "$6.98 billion",
#             "Product B": "$2.35 billion",
#             "Product C": "-$0.64 billion"
#         },
#         "Effective Tax Rate": "12%",
#         "Deferred Tax Assets": "$4.95 billion",
#         "Deferred Tax Liabilities": "$280 million",
#         "Foreign Income Percentage": "80%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product A": "$24.52 billion",
#             "Product B": "$11.82 billion",
#             "Product C": "$7.93 billion"
#         },
#         "Net Income": {
#             "Product A": "$6.42 billion",
#             "Product B": "$2.14 billion",
#             "Product C": "-$0.72 billion"
#         },
#         "Effective Tax Rate": "11.5%",
#         "Deferred Tax Assets": "$4.75 billion",
#         "Deferred Tax Liabilities": "$240 million",
#         "Foreign Income Percentage": "75%"
#     },
#     "2019": {
#         "Revenue": {
#             "Product A": "$23.31 billion",
#             "Product B": "$11.36 billion",
#             "Product C": "$7.12 billion"
#         },
#         "Net Income": {
#             "Product A": "$5.98 billion",
#             "Product B": "$1.98 billion",
#             "Product C": "-$0.83 billion"
#         },
#         "Effective Tax Rate": "10.9%",
#         "Deferred Tax Assets": "$4.52 billion",
#         "Deferred Tax Liabilities": "$200 million",
#         "Foreign Income Percentage": "70%"
#     }
# }
# Saved insights for AAPL - 0000320193-20-000096 to insights/AAPL/0000320193-20-000096_insights.json
# Extracted JSON data for AAPL - 0000320193-19-000119: {
#     "2022": {
#         "Revenue": {
#             "Product A": "$100 million",
#             "Product B": "$75 million"
#         },
#         "Net Income": {
#             "Product A": "$25 million",
#             "Product B": "-$10 million"
#         },
#         "Effective Tax Rate": "15%",
#         "Deferred Tax Assets": "$50 million",
#         "Deferred Tax Liabilities": "$10 million",
#         "Foreign Income Percentage": "75%"
#     },
#     "2021": {
#         "Revenue": {
#             "Product A": "$95 million",
#             "Product B": "$80 million"
#         },
#         "Net Income": {
#             "Product A": "$20 million",
#             "Product B": "-$5 million"
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$40 million",
#         "Deferred Tax Liabilities": "$15 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for AAPL - 0000320193-19-000119 to insights/AAPL/0000320193-19-000119_insights.json
# Extracted JSON data for AAPL - 0000320193-18-000145: {
#     "2022": {
#         "Revenue": {
#             "Compute & Networking": "$26.938 billion",
#             "Graphics": "$11.718 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$7.634 billion",
#             "Graphics": "$2.462 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Compute & Networking": "$24.672 billion",
#             "Graphics": "$9.712 billion"
#         },
#         "Net Income": {
#             "Compute & Networking": "$6.575 billion",
#             "Graphics": "$1.917 billion"
#         },
#         "Effective Tax Rate": "10.5%",
#         "Deferred Tax Assets": "$4.78 billion",
#         "Deferred Tax Liabilities": "$385 million",
#         "Foreign Income Percentage": "83%"
#     }
# }
# Saved insights for AAPL - 0000320193-18-000145 to insights/AAPL/0000320193-18-000145_insights.json
# Extracted JSON data for AAPL - 0000320193-17-000070: {
#     "2020": {
#         "Revenue": {
#             "Product-wise": {
#                 "Compute & Networking": "$26.938 billion",
#                 "Graphics": "$11.718 billion"
#             }
#         },
#         "Net Income": {
#             "Product-wise": {
#                 "Compute & Networking": "$7.634 billion",
#                 "Graphics": "$2.462 billion"
#             }
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     }
# }
# Saved insights for AAPL - 0000320193-17-000070 to insights/AAPL/0000320193-17-000070_insights.json
# Extracted JSON data for MSFT - 0001564590-22-026876: {
#         "2022": {
#             "Revenue": {
#                 "Total": "$6,393 million",
#                 "Laptops": "$2,188 million",
#                 "Desktops": "$2,986 million",
#                 "Tablets": "$1,219 million"
#             },
#             "Net Income": {
#                 "Total": "$1,087 million",
#                 "Laptops": "$380 million",
#                 "Desktops": "$483 million",
#                 "Tablets": "$224 million"
#             },
#             "Effective Tax Rate": "17.1%",
#             "Deferred Tax Assets": "$360 million",
#             "Deferred Tax Liabilities": "$25 million",
#             "Foreign Income Percentage": "36.7%"
#         },
#         "2021": {
#             "Revenue": {
#                 "Total": "$5,581 million",
#                 "Laptops": "$1,840 million",
#                 "Desktops": "$2,636 million",
#                 "Tablets": "$1,105 million"
#             },
#             "Net Income": {
#                 "Total": "$1,030 million",
#                 "Laptops": "$348 million",
#                 "Desktops": "$429 million",
#                 "Tablets": "$253 million"
#             },
#             "Effective Tax Rate": "18.2%",
#             "Deferred Tax Assets": "$368 million",
#             "Deferred Tax Liabilities": "$31 million",
#             "Foreign Income Percentage": "38.2%"
#         }
#     }
# Saved insights for MSFT - 0001564590-22-026876 to insights/MSFT/0001564590-22-026876_insights.json
# Extracted JSON data for MSFT - 0001564590-21-039151: {
#     "2020": {
#         "Revenue": {
#             "Total Revenue": "$26.438 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$19.418 billion",
#                 "Graphics": "$7.020 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$7.411 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$5.322 billion",
#                 "Graphics": "$2.089 billion"
#             }
#         },
#         "Effective Tax Rate": "9.6%",
#         "Deferred Tax Assets": "$5.239 billion",
#         "Deferred Tax Liabilities": "$434 million",
#         "Foreign Income Percentage": "90%"
#     },
#     "2019": {
#         "Revenue": {
#             "Total Revenue": "$21.411 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$15.908 billion",
#                 "Graphics": "$5.503 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$5.472 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$4.248 billion",
#                 "Graphics": "$1.224 billion"
#             }
#         },
#         "Effective Tax Rate": "6.7%",
#         "Deferred Tax Assets": "$4.918 billion",
#         "Deferred Tax Liabilities": "$301 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2018": {
#         "Revenue": {
#             "Total Revenue": "$20.529 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$15.727 billion",
#                 "Graphics": "$4.802 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$5.294 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$4.294 billion",
#                 "Graphics": "$1.000 billion"
#             }
#         },
#         "Effective Tax Rate": "8.8%",
#         "Deferred Tax Assets": "$4.563 billion",
#         "Deferred Tax Liabilities": "$266 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for MSFT - 0001564590-21-039151 to insights/MSFT/0001564590-21-039151_insights.json
# Extracted JSON data for MSFT - 0001564590-20-034944: {
#     "2022": {
#         "Revenue": {
#             "Product A": "$5.9 billion",
#             "Product B": "$3.2 billion",
#             "Product C": "$2.3 billion"
#         },
#         "Net Income": {
#             "Product A": "$1.9 billion",
#             "Product B": "$0.8 billion",
#             "Product C": "$0.4 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Product A": "$5.1 billion",
#             "Product B": "$3.5 billion",
#             "Product C": "$2.7 billion"
#         },
#         "Net Income": {
#             "Product A": "$1.6 billion",
#             "Product B": "$0.9 billion",
#             "Product C": "$0.3 billion"
#         },
#         "Effective Tax Rate": "10.5%",
#         "Deferred Tax Assets": "$4.7 billion",
#         "Deferred Tax Liabilities": "$412 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for MSFT - 0001564590-20-034944 to insights/MSFT/0001564590-20-034944_insights.json
# Extracted JSON data for MSFT - 0001564590-19-027952: {
#     "2021": {
#         "Revenue": {
#             "Product Sales": "$4.26 billion",
#             "Software and Services": "$7.52 billion"
#         },
#         "Net Income": {
#             "Product Sales": "$1.28 billion",
#             "Software and Services": "$1.93 billion"
#         },
#         "Effective Tax Rate": "12.8%",
#         "Deferred Tax Assets": "$1.98 billion",
#         "Deferred Tax Liabilities": "$1.06 billion",
#         "Foreign Income Percentage": "60%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product Sales": "$3.97 billion",
#             "Software and Services": "$8.14 billion"
#         },
#         "Net Income": {
#             "Product Sales": "$1.09 billion",
#             "Software and Services": "$2.44 billion"
#         },
#         "Effective Tax Rate": "13.5%",
#         "Deferred Tax Assets": "$1.74 billion",
#         "Deferred Tax Liabilities": "$1.18 billion",
#         "Foreign Income Percentage": "55%"
#     },
#     "2019": {
#         "Revenue": {
#             "Product Sales": "$3.86 billion",
#             "Software and Services": "$8.52 billion"
#         },
#         "Net Income": {
#             "Product Sales": "$1.01 billion",
#             "Software and Services": "$2.55 billion"
#         },
#         "Effective Tax Rate": "14.2%",
#         "Deferred Tax Assets": "$1.57 billion",
#         "Deferred Tax Liabilities": "$1.23 billion",
#         "Foreign Income Percentage": "50%"
#     }
# }
# Saved insights for MSFT - 0001564590-19-027952 to insights/MSFT/0001564590-19-027952_insights.json
# Extracted JSON data for MSFT - 0001564590-18-019062: {
#     "2021": {
#         "Revenue": {
#             "Total Revenue": "$89.0 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$26.9 billion",
#                 "Enterprise, Embedded, and Semi-Custom": "$62.1 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$11.9 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$7.6 billion",
#                 "Enterprise, Embedded, and Semi-Custom": "$4.3 billion"
#             }
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.1 billion",
#         "Deferred Tax Liabilities": "$0.3 billion",
#         "Foreign Income Percentage": "85%"
#     },
#     "2020": {
#         "Revenue": {
#             "Total Revenue": "$78.0 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$26.9 billion",
#                 "Enterprise, Embedded, and Semi-Custom": "$51.1 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$9.7 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$5.5 billion",
#                 "Enterprise, Embedded, and Semi-Custom": "$4.2 billion"
#             }
#         },
#         "Effective Tax Rate": "11.2%",
#         "Deferred Tax Assets": "$4.2 billion",
#         "Deferred Tax Liabilities": "$0.3 billion",
#         "Foreign Income Percentage": "85%"
#     }
# }
# Saved insights for MSFT - 0001564590-18-019062 to insights/MSFT/0001564590-18-019062_insights.json
# Extracted JSON data for MSFT - 0001564590-17-014900: {
#     "2021": {
#         "Revenue": {
#             "Product": {
#                 "Compute & Networking": "$26.938 billion",
#                 "Graphics": "$11.718 billion"
#             },
#             "Source": "10-k filing"
#         },
#         "Net Income": {
#             "Product": {
#                 "Compute & Networking": "$7.634 billion",
#                 "Graphics": "$2.462 billion"
#             },
#             "Source": "10-k filing"
#         },
#         "Effective Tax Rate": {
#             "Value": "9.9%",
#             "Source": "10-k filing"
#         },
#         "Deferred Tax Assets": {
#             "Value": "$5.05 billion",
#             "Source": "10-k filing"
#         },
#         "Deferred Tax Liabilities": {
#             "Value": "$339 million",
#             "Source": "10-k filing"
#         },
#         "Foreign Income Percentage": {
#             "Value": "85%",
# ...
#     },
#     "Effective Tax Rate": "9.8%",
#     "Deferred Tax Assets": "$36.8 million",
#     "Deferred Tax Liabilities": "$4.1 million",
#     "Foreign Income Percentage": "20%"
#   }
# }
# Saved insights for TSLA - 0001564590-20-004475 to insights/TSLA/0001564590-20-004475_insights.json
# Extracted JSON data for TSLA - 0001564590-19-003165: {
#     "2020": {
#         "Revenue": {
#             "Product-wise": {
#                 "Compute & Networking": "$26.938 billion",
#                 "Graphics": "$11.718 billion"
#             },
#             "Total": "$38.656 billion"
#         },
#         "Net Income": {
#             "Product-wise": {
#                 "Compute & Networking": "$7.634 billion",
#                 "Graphics": "$2.462 billion"
#             },
#             "Total": "$10.096 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2019": {
#         "Revenue": {
#             "Product-wise": {
#                 "Compute & Networking": "$23.272 billion",
#                 "Graphics": "$9.712 billion"
#             },
#             "Total": "$32.984 billion"
#         },
#         "Net Income": {
#             "Product-wise": {
#                 "Compute & Networking": "$6.734 billion",
#                 "Graphics": "$2.039 billion"
#             },
#             "Total": "$8.773 billion"
#         },
#         "Effective Tax Rate": "10.2%",
#         "Deferred Tax Assets": "$4.02 billion",
#         "Deferred Tax Liabilities": "$234 million",
#         "Foreign Income Percentage": "82%"
#     },
#     "2018": {
#         "Revenue": {
#             "Product-wise": {
#                 "Compute & Networking": "$18.328 billion",
#                 "Graphics": "$6.479 billion"
#             },
#             "Total": "$24.807 billion"
#         },
#         "Net Income": {
#             "Product-wise": {
#                 "Compute & Networking": "$5.301 billion",
#                 "Graphics": "$1.305 billion"
#             },
#             "Total": "$6.606 billion"
#         },
#         "Effective Tax Rate": "12%",
#         "Deferred Tax Assets": "$3.16 billion",
#         "Deferred Tax Liabilities": "$189 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for TSLA - 0001564590-19-003165 to insights/TSLA/0001564590-19-003165_insights.json
# Extracted JSON data for TSLA - 0001564590-18-002956: {
#     "2021": {
#         "Revenue": {
#             "Total": "$254.78 billion",
#             "Compute & Networking": "$79.94 billion",
#             "Graphics": "$32.87 billion",
#             "Data Center": "$50.98 billion",
#             "PC & Gaming": "$12.18 billion",
#             "Enterprise, Embedded, and Semi-Custom": "$78.81 billion"
#         },
#         "Net Income": {
#             "Total": "$13.34 billion",
#             "Compute & Networking": "$5.37 billion",
#             "Graphics": "$1.91 billion",
#             "Data Center": "$4.75 billion",
#             "PC & Gaming": "$1.51 billion",
#             "Enterprise, Embedded, and Semi-Custom": "$1.70 billion"
#         },
#         "Effective Tax Rate": "11%",
#         "Deferred Tax Assets": "$4.63 billion",
#         "Deferred Tax Liabilities": "$273 million",
#         "Foreign Income Percentage": "88%"
#     },
#     "2020": {
#         "Revenue": {
#             "Total": "$249.94 billion",
#             "Compute & Networking": "$74.52 billion",
#             "Graphics": "$28.61 billion",
#             "Data Center": "$41.01 billion",
#             "PC & Gaming": "$8.73 billion",
#             "Enterprise, Embedded, and Semi-Custom": "$97.07 billion"
#         },
#         "Net Income": {
#             "Total": "$11.44 billion",
#             "Compute & Networking": "$4.11 billion",
#             "Graphics": "$1.12 billion",
#             "Data Center": "$3.44 billion",
#             "PC & Gaming": "$1.18 billion",
#             "Enterprise, Embedded, and Semi-Custom": "$1.69 billion"
#         },
#         "Effective Tax Rate": "12%",
#         "Deferred Tax Assets": "$4.42 billion",
#         "Deferred Tax Liabilities": "$287 million",
#         "Foreign Income Percentage": "84%"
#     }
# }
# Saved insights for TSLA - 0001564590-18-002956 to insights/TSLA/0001564590-18-002956_insights.json
# Extracted JSON data for TSLA - 0001564590-17-003118: {
#     "2021": {
#         "Revenue": {
#             "Product A": "$1.1 billion",
#             "Product B": "$5.5 billion"
#         },
#         "Net Income": {
#             "Product A": "$0.2 billion",
#             "Product B": "$1.1 billion"
#         },
#         "Effective Tax Rate": "15%",
#         "Deferred Tax Assets": "$100 million",
#         "Deferred Tax Liabilities": "$50 million",
#         "Foreign Income Percentage": "70%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product A": "$0.9 billion",
#             "Product B": "$5.0 billion"
#         },
#         "Net Income": {
#             "Product A": "$0.1 billion",
#             "Product B": "$1.0 billion"
#         },
#         "Effective Tax Rate": "20%",
#         "Deferred Tax Assets": "$80 million",
#         "Deferred Tax Liabilities": "$40 million",
#         "Foreign Income Percentage": "65%"
#     }
# }
# Saved insights for TSLA - 0001564590-17-003118 to insights/TSLA/0001564590-17-003118_insights.json
# Extracted JSON data for TSLA - 0001564590-16-013195: {
#     "2021": {
#         "Revenue": {
#             "Product Wise": {
#                 "Compute & Networking": "$26.938 billion",
#                 "Graphics": "$11.718 billion"
#             }
#         },
#         "Net Income": {
#             "Product Wise": {
#                 "Compute & Networking": "$7.634 billion",
#                 "Graphics": "$2.462 billion"
#             }
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product Wise": {
#                 "Compute & Networking": "$25.745 billion",
#                 "Graphics": "$10.897 billion"
#             }
#         },
#         "Net Income": {
#             "Product Wise": {
#                 "Compute & Networking": "$6.907 billion",
#                 "Graphics": "$1.863 billion"
#             }
#         },
#         "Effective Tax Rate": "9.5%",
#         "Deferred Tax Assets": "$4.78 billion",
#         "Deferred Tax Liabilities": "$345 million",
#         "Foreign Income Percentage": "86%"
#     }
# }
# Saved insights for TSLA - 0001564590-16-013195 to insights/TSLA/0001564590-16-013195_insights.json
# Extracted JSON data for TSLA - 0001564590-15-001031: {
#     "2021": {
#         "Revenue": {
#             "Product 1": "$15.3 billion",
#             "Product 2": "$6.8 billion",
#             "Product 3": "$2.9 billion"
#         },
#         "Net Income": {
#             "Product 1": "$2.1 billion",
#             "Product 2": "$1.2 billion",
#             "Product 3": "$0.5 billion"
#         },
#         "Effective Tax Rate": "12%",
#         "Deferred Tax Assets": "$1.8 billion",
#         "Deferred Tax Liabilities": "$0.2 billion",
#         "Foreign Income Percentage": "72%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product 1": "$13.5 billion",
#             "Product 2": "$5.9 billion",
#             "Product 3": "$2.5 billion"
#         },
#         "Net Income": {
#             "Product 1": "$1.8 billion",
#             "Product 2": "$1 billion",
#             "Product 3": "$0.4 billion"
#         },
#         "Effective Tax Rate": "11%",
#         "Deferred Tax Assets": "$1.5 billion",
#         "Deferred Tax Liabilities": "$0.1 billion",
#         "Foreign Income Percentage": "70%"
#     }
# }
# Saved insights for TSLA - 0001564590-15-001031 to insights/TSLA/0001564590-15-001031_insights.json
# Extracted JSON data for TSLA - 0001193125-14-069681: {
#     "2022": {
#         "Revenue": {
#             "Product A": "$1.23 billion",
#             "Product B": "$3.45 billion",
#             "Product C": "$6.78 billion"
#         },
#         "Net Income": {
#             "Product A": "$0.12 billion",
#             "Product B": "$0.34 billion",
#             "Product C": "$1.56 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Product A": "$1.11 billion",
#             "Product B": "$2.22 billion",
#             "Product C": "$4.44 billion"
#         },
#         "Net Income": {
#             "Product A": "-$0.11 billion",
#             "Product B": "-$0.22 billion",
#             "Product C": "-$0.44 billion"
#         },
#         "Effective Tax Rate": "10.5%",
#         "Deferred Tax Assets": "$4.50 billion",
#         "Deferred Tax Liabilities": "$338 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for TSLA - 0001193125-14-069681 to insights/TSLA/0001193125-14-069681_insights.json
# Extracted JSON data for TSLA - 0001193125-13-096241: {
#     "2020": {
#         "Revenue": {
#             "Total Revenue": "$13.76 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$9.76 billion",
#                 "Graphics": "$4 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$2.91 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$2.2 billion",
#                 "Graphics": "$710 million"
#             }
#         },
#         "Effective Tax Rate": "16.8%",
#         "Deferred Tax Assets": "$3.42 billion",
#         "Deferred Tax Liabilities": "$47 million",
#         "Foreign Income Percentage": "80%"
#     },
#     "2019": {
#         "Revenue": {
#             "Total Revenue": "$11.06 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$7.76 billion",
#                 "Graphics": "$3.3 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$1.51 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$1.14 billion",
#                 "Graphics": "$370 million"
#             }
#         },
#         "Effective Tax Rate": "18.6%",
#         "Deferred Tax Assets": "$2.23 billion",
#         "Deferred Tax Liabilities": "$44 million",
#         "Foreign Income Percentage": "75%"
#     },
#     "2018": {
#         "Revenue": {
#             "Total Revenue": "$9.71 billion",
#             "Product Revenue": {
#                 "Compute & Networking": "$6.66 billion",
#                 "Graphics": "$3.05 billion"
#             }
#         },
#         "Net Income": {
#             "Total Net Income": "$1.02 billion",
#             "Product Net Income": {
#                 "Compute & Networking": "$771 million",
#                 "Graphics": "$250 million"
#             }
#         },
#         "Effective Tax Rate": "19.2%",
#         "Deferred Tax Assets": "$1.72 billion",
#         "Deferred Tax Liabilities": "$38 million",
#         "Foreign Income Percentage": "70%"
#     }
# }
# Saved insights for TSLA - 0001193125-13-096241 to insights/TSLA/0001193125-13-096241_insights.json
# Extracted JSON data for TSLA - 0001193125-12-081990: {
#     "2021": {
#         "Revenue": {
#             "Product A": "$10.5 billion",
#             "Product B": "$7.2 billion"
#         },
#         "Net Income": {
#             "Product A": "$1.5 billion",
#             "Product B": "$0.8 billion"
#         },
#         "Effective Tax Rate": "12%",
#         "Deferred Tax Assets": "$2.3 billion",
#         "Deferred Tax Liabilities": "$0.5 billion",
#         "Foreign Income Percentage": "70%"
#     },
#     "2020": {
#         "Revenue": {
#             "Product A": "$9.8 billion",
#             "Product B": "$6.5 billion"
#         },
#         "Net Income": {
#             "Product A": "$1.2 billion",
#             "Product B": "$0.6 billion"
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$2.1 billion",
#         "Deferred Tax Liabilities": "$0.4 billion",
#         "Foreign Income Percentage": "65%"
#     }
# }
# Saved insights for TSLA - 0001193125-12-081990 to insights/TSLA/0001193125-12-081990_insights.json
# Extracted JSON data for TSLA - 0001193125-11-054847: {
#     "2022": {
#         "Revenue": {
#             "Product1": "10.5%",
#             "Product2": "14.2%",
#             "Product3": "18.3%"
#         },
#         "Net Income": {
#             "Product1": "$5.7 billion",
#             "Product2": "$3.5 billion",
#             "Product3": "$1.6 billion"
#         },
#         "Effective Tax Rate": "9.9%",
#         "Deferred Tax Assets": "$5.05 billion",
#         "Deferred Tax Liabilities": "$339 million",
#         "Foreign Income Percentage": "85%"
#     },
#     "2021": {
#         "Revenue": {
#             "Product1": "9.8%",
#             "Product2": "12.4%",
#             "Product3": "16.7%"
#         },
#         "Net Income": {
#             "Product1": "$4.9 billion",
#             "Product2": "$3.1 billion",
#             "Product3": "$1.3 billion"
#         },
#         "Effective Tax Rate": "9.5%",
#         "Deferred Tax Assets": "$4.75 billion",
#         "Deferred Tax Liabilities": "$245 million",
#         "Foreign Income Percentage": "83%"
#     }
# }
# Saved insights for TSLA - 0001193125-11-054847 to insights/TSLA/0001193125-11-054847_insights.json
# Extracted JSON data for TSLA - 0000950170-23-001409: {
#   "2019": {
#     "Revenue": {
#       "Product A": "$5 billion",
#       "Product B": "$1 billion"
#     },
#     "Net Income": {
#       "Product A": "$2 billion",
#       "Product B": "-$500 million"
#     },
#     "Effective Tax Rate": "20%",
#     "Deferred Tax Assets": "$1 billion",
#     "Deferred Tax Liabilities": "$500 million",
#     "Foreign Income Percentage": "75%"
#   },
#   "2020": {
#     "Revenue": {
#       "Product A": "$6 billion",
#       "Product B": "$1 billion"
#     },
#     "Net Income": {
#       "Product A": "$2.5 billion",
#       "Product B": "-$300 million"
#     },
#     "Effective Tax Rate": "18%",
#     "Deferred Tax Assets": "$1.2 billion",
#     "Deferred Tax Liabilities": "$600 million",
#     "Foreign Income Percentage": "80%"
#   },
#   "2021": {
#     "Revenue": {
#       "Product A": "$7 billion",
#       "Product B": "$1 billion"
#     },
#     "Net Income": {
#       "Product A": "$3 billion",
#       "Product B": "-$200 million"
#     },
#     "Effective Tax Rate": "15%",
#     "Deferred Tax Assets": "$1.5 billion",
#     "Deferred Tax Liabilities": "$800 million",
#     "Foreign Income Percentage": "85%"
#   },
#   "2022": {
#     "Revenue": {
#       "Product A": "$8 billion",
#       "Product B": "$2 billion"
#     },
#     "Net Income": {
#       "Product A": "$3.5 billion",
#       "Product B": "-$100 million"
#     },
#     "Effective Tax Rate": "12%",
#     "Deferred Tax Assets": "$2 billion",
#     "Deferred Tax Liabilities": "$1 billion",
#     "Foreign Income Percentage": "90%"
#   }
# }
# Saved insights for TSLA - 0000950170-23-001409 to insights/TSLA/0000950170-23-001409_insights.json
# Extracted JSON data for TSLA - 0000950170-22-000796: {
#     "2022": {
#         "Revenue": {
#             "Product A": "$1 billion",
#             "Product B": "$2 billion",
#             "Product C": "$3 billion"
#         },
#         "Net Income": {
#             "Product A": "$100 million",
#             "Product B": "$200 million",
#             "Product C": "-$50 million"
#         },
#         "Effective Tax Rate": "15%",
#         "Deferred Tax Assets": "$500 million",
#         "Deferred Tax Liabilities": "$100 million",
#         "Foreign Income Percentage": "75%"
#     },
#     "2021": {
#         "Revenue": {
#             "Product A": "$2 billion",
#             "Product B": "$3 billion",
#             "Product D": "$1 billion"
#         },
#         "Net Income": {
#             "Product A": "$200 million",
#             "Product B": "-$100 million",
#             "Product D": "$50 million"
#         },
#         "Effective Tax Rate": "10%",
#         "Deferred Tax Assets": "$400 million",
#         "Deferred Tax Liabilities": "$50 million",
#         "Foreign Income Percentage": "80%"
#     }
# }
# Saved insights for TSLA - 0000950170-22-000796 to insights/TSLA/0000950170-22-000796_insights.json
# Completed processing all companies.

# %%
def create_json_files_list(base_folder):
    """
    Creates a list of JSON files along with their corresponding years and company names.

    Parameters:
    - base_folder (str): Path to the base folder containing the JSON files.

    Returns:
    - list: A list of tuples, each containing the file path, year, and company name.
    """
    json_files = []
    for root, _, files in os.walk(base_folder):
        company_name = os.path.basename(root)
        year = 2023
        for file in files:
            if file.endswith('.json'):
                json_files.append((os.path.join(root, file), year, company_name))
                year -= 1
    return json_files

def get_summarized_metrics(data):
    """
    Summarizes the total revenue and net income from the provided JSON data using OpenAI's GPT model.

    Parameters:
    - data (dict): The JSON data to be analyzed.

    Returns:
    - str: The summarized metrics in a formatted text.
    """
    prompt = f"Analyze the following JSON data and summarize the total revenue and net income:\n\n{json.dumps(data, indent=2)}\n\n"
    prompt += "Provide the total revenue, total net income, effective tax rate, and foreign income percentage in the format:\nRevenue: [value]\nNet Income: [value]\nEffective Tax Rate: [value]\nForeign Income Percentage: [value]"

    response = openai.Completion.create(
        model="gpt-3.5-turbo-instruct",
        prompt=prompt,
        max_tokens=150
    )
    
    return response.choices[0].text.strip()

def extract_metrics(summary_text):
    """
    Extracts specific financial metrics from the summarized text.

    Parameters:
    - summary_text (str): The summarized text containing financial metrics.

    Returns:
    - tuple: A tuple containing the revenue, net income, tax rate, and foreign income percentage.
    """
    lines = summary_text.split('\n')
    revenue = None
    net_income = None
    tax_rate = None
    foreign_income = None
    
    for line in lines:
        if 'Revenue' in line:
            value = line.split(':', 1)[1].strip().replace('$', '').replace(' million', '').replace(' billion', '').strip()
            try:
                revenue = float(value)
            except ValueError:
                continue
        elif 'Net Income' in line:
            value = line.split(':', 1)[1].strip().replace('$', '').replace(' million', '').replace(' billion', '').strip()
            try:
                net_income = float(value)
            except ValueError:
                continue
        elif 'Effective Tax Rate' in line:
            value = line.split(':', 1)[1].strip().replace('%', '').strip()
            try:
                tax_rate = float(value)
            except ValueError:
                continue
        elif 'Foreign Income Percentage' in line:
            value = line.split(':', 1)[1].strip().replace('%', '').strip()
            try:
                foreign_income = float(value)
            except ValueError:
                continue

    return revenue, net_income, tax_rate, foreign_income

def analyze_json_file(json_file_path, year):
    """
    Analyzes a JSON file to extract and summarize financial metrics.

    Parameters:
    - json_file_path (str): Path to the JSON file to be analyzed.
    - year (int): The year corresponding to the JSON file.

    Returns:
    - tuple: A tuple containing the year, revenue, net income, tax rate, and foreign income percentage.
    """
    print(f"Processing {json_file_path}")  # Debug statement
    with open(json_file_path, 'r') as file:
        data = json.load(file)

    summary_text = get_summarized_metrics(data)
    revenue, net_income, tax_rate, foreign_income = extract_metrics(summary_text)
    
    print(f"Extracted - Year: {year}, Revenue: {revenue}, Net Income: {net_income}, Tax Rate: {tax_rate}, Foreign Income: {foreign_income}")  # Debug statement

    if revenue is not None and net_income is not None:
        return (year, revenue, net_income, tax_rate, foreign_income)
    else:
        return None

def plot_metrics(metrics, company_name):
    """
    Plots the financial metrics for a company over the years.

    Parameters:
    - metrics (list): A list of tuples containing the financial metrics.
    - company_name (str): The name of the company.
    """
    if not metrics:
        print(f"No data to plot for {company_name}.")
        return

    years, revenues, net_incomes, tax_rates, foreign_incomes = zip(*metrics)

    x = range(len(years))
    
    # Plot Revenue and Net Income
    plt.figure(figsize=(15, 8))
    plt.bar(x, revenues, width=0.4, label='Revenue', align='center')
    plt.bar(x, net_incomes, width=0.4, label='Net Income', align='edge')
    
    plt.xlabel('Year')
    plt.ylabel('Value (in billions)')
    plt.title(f'{company_name} Revenue and Net Income Over the Years')
    plt.xticks(x, years, fontsize=8, rotation=45)
    plt.legend()
    
    visualization_dir = f'visualizations/{company_name}'
    os.makedirs(visualization_dir, exist_ok=True)
    
    plt.savefig(f'{visualization_dir}/revenue_net_income_over_years.png')
    plt.close()

    # Plot Effective Tax Rate
    plt.figure(figsize=(15, 8))
    plt.plot(x, tax_rates, marker='o', label='Effective Tax Rate')
    
    plt.xlabel('Year')
    plt.ylabel('Effective Tax Rate (%)')
    plt.title(f'{company_name} Effective Tax Rate Over the Years')
    plt.xticks(x, years, fontsize=8, rotation=45)
    plt.legend()
    
    plt.savefig(f'{visualization_dir}/effective_tax_rate_over_years.png')
    plt.close()

    # Plot Foreign Income Percentage
    plt.figure(figsize=(15, 8))
    plt.plot(x, foreign_incomes, marker='o', label='Foreign Income Percentage')
    
    plt.xlabel('Year')
    plt.ylabel('Foreign Income Percentage (%)')
    plt.title(f'{company_name} Foreign Income Percentage Over the Years')
    plt.xticks(x, years, fontsize=8, rotation=45)
    plt.legend()
    
    plt.savefig(f'{visualization_dir}/foreign_income_percentage_over_years.png')
    plt.close()

base_folder = '/Users/adi_shukla/Documents/sec-edgar-proj/insights'

json_files_list = create_json_files_list(base_folder)

# Group JSON files by company name
companies = {}
for json_file, year, company_name in json_files_list:
    if company_name not in companies:
        companies[company_name] = []
    companies[company_name].append((json_file, year))

# Process and plot metrics for each company
for company_name, company_json_files in companies.items():
    metrics = []
    for json_file, year in company_json_files:
        metric = analyze_json_file(json_file, year)
        if metric:
            metrics.append(metric)
    if metrics:
        plot_metrics(metrics, company_name)
    else:
        print(f"No metrics to plot for {company_name}.")

print("Completed processing the specified JSON files.")
# Out:
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-13-416534_insights.json
# Extracted - Year: 2023, Revenue: 51.655, Net Income: 13.791, Tax Rate: 9.9, Foreign Income: 85.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001047469-02-007674_insights.json
# Extracted - Year: 2022, Revenue: 508.23, Net Income: 90.562, Tax Rate: 10.2, Foreign Income: 84.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-21-000105_insights.json
# Extracted - Year: 2021, Revenue: None, Net Income: None, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001628280-16-020309_insights.json
# Extracted - Year: 2020, Revenue: 25.93, Net Income: 10.634, Tax Rate: 9.9, Foreign Income: 85.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-18-000145_insights.json
# Extracted - Year: 2019, Revenue: 51.61, Net Income: 14.09, Tax Rate: 10.2, Foreign Income: 84.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-20-000096_insights.json
# Extracted - Year: 2018, Revenue: 73.48, Net Income: 16.64, Tax Rate: 11.46, Foreign Income: 75.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001104659-05-058421_insights.json
# Extracted - Year: 2017, Revenue: 18.0, Net Income: -500.0, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-10-238044_insights.json
# Extracted - Year: 2016, Revenue: 250.0, Net Income: 125.0, Tax Rate: 17.5, Foreign Income: 75.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-08-224958_insights.json
# Extracted - Year: 2015, Revenue: None, Net Income: None, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000912057-00-053623_insights.json
# Extracted - Year: 2014, Revenue: 50.544, Net Income: 17.998, Tax Rate: 10.2, Foreign Income: 83.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000912057-99-010244_insights.json
# Extracted - Year: 2013, Revenue: 6.9, Net Income: 4.0, Tax Rate: 17.5, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-19-000119_insights.json
# Extracted - Year: 2012, Revenue: 175.0, Net Income: 40.0, Tax Rate: 12.5, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-23-000106_insights.json
# Extracted - Year: 2011, Revenue: 549.03, Net Income: 146.097, Tax Rate: 8.8, Foreign Income: 73.9
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-95-000016_insights.json
# Extracted - Year: 2010, Revenue: 53.655, Net Income: 15.096, Tax Rate: 9.95, Foreign Income: 85.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001104659-06-084288_insights.json
# Extracted - Year: 2009, Revenue: 0.0, Net Income: 0.0, Tax Rate: 0.0, Foreign Income: 0.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-22-000108_insights.json
# Extracted - Year: 2008, Revenue: 72.21, Net Income: -16.416, Tax Rate: 12.3, Foreign Income: 83.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001047469-03-041604_insights.json
# Extracted - Year: 2007, Revenue: None, Net Income: 322.884, Tax Rate: 11.04, Foreign Income: 69.8
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-17-000070_insights.json
# Extracted - Year: 2006, Revenue: 38.656, Net Income: 10.096, Tax Rate: 9.9, Foreign Income: 85.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001047469-07-009340_insights.json
# Extracted - Year: 2005, Revenue: 190.0, Net Income: 19.0, Tax Rate: 9.5, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-11-282113_insights.json
# Extracted - Year: 2004, Revenue: None, Net Income: None, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-15-356351_insights.json
# Extracted - Year: 2003, Revenue: 51.592, Net Income: 12.296, Tax Rate: 10.05, Foreign Income: 83.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-09-214859_insights.json
# Extracted - Year: 2002, Revenue: 15.0, Net Income: 7.0, Tax Rate: 9.0, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-94-000016_insights.json
# Extracted - Year: 2001, Revenue: None, Net Income: None, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0000320193-96-000023_insights.json
# Extracted - Year: 2000, Revenue: 294.9, Net Income: 53.1, Tax Rate: 11.1, Foreign Income: 83.25
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-12-444068_insights.json
# Extracted - Year: 1999, Revenue: 9.5, Net Income: 0.9, Tax Rate: 19.0, Foreign Income: 73.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001193125-14-383437_insights.json
# Extracted - Year: 1998, Revenue: 27.0, Net Income: 6.5, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001047469-04-035975_insights.json
# Extracted - Year: 1997, Revenue: 56.5, Net Income: 6.6, Tax Rate: 21.75, Foreign Income: 82.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/AAPL/0001047469-97-006960_insights.json
# Extracted - Year: 1996, Revenue: 274.515, Net Income: 90.027, Tax Rate: 16.9, Foreign Income: 60.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0000950170-22-000796_insights.json
# Extracted - Year: 2023, Revenue: 6.0, Net Income: 300.0, Tax Rate: 10.6, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0000950170-23-001409_insights.json
# Extracted - Year: 2022, Revenue: 22.0, Net Income: 9.0, Tax Rate: 16.25, Foreign Income: 82.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001193125-12-081990_insights.json
# Extracted - Year: 2021, Revenue: 20.3, Net Income: 2.7, Tax Rate: 11.0, Foreign Income: 68.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001564590-21-004599_insights.json
# Extracted - Year: 2020, Revenue: 274.515, Net Income: 57.411, Tax Rate: 14.4, Foreign Income: 65.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001193125-11-054847_insights.json
# Extracted - Year: 2019, Revenue: 32.98, Net Income: 15.9, Tax Rate: 9.7, Foreign Income: 84.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001193125-14-069681_insights.json
# Extracted - Year: 2018, Revenue: None, Net Income: None, Tax Rate: 10.2, Foreign Income: 82.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001564590-15-001031_insights.json
# Extracted - Year: 2017, Revenue: 22.7, Net Income: 3.8, Tax Rate: 11.5, Foreign Income: 71.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001564590-20-004475_insights.json
# Extracted - Year: 2016, Revenue: 742.2, Net Income: 44.1, Tax Rate: 15.3, Foreign Income: 17.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001628280-24-002390_insights.json
# Extracted - Year: 2015, Revenue: 38.0, Net Income: 8.0, Tax Rate: 13.0, Foreign Income: 17.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001564590-18-002956_insights.json
# Extracted - Year: 2014, Revenue: 504.72, Net Income: 24.78, Tax Rate: 11.0, Foreign Income: 88.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001193125-13-096241_insights.json
# Extracted - Year: 2013, Revenue: 13.76, Net Income: 2.91, Tax Rate: 16.8, Foreign Income: 80.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001564590-16-013195_insights.json
# Extracted - Year: 2012, Revenue: 38.656, Net Income: 10.571, Tax Rate: 9.7, Foreign Income: 85.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001564590-17-003118_insights.json
# Extracted - Year: 2011, Revenue: 6.6, Net Income: 1.3, Tax Rate: 15.0, Foreign Income: 70.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/TSLA/0001564590-19-003165_insights.json
# Extracted - Year: 2010, Revenue: 96.447, Net Income: 25.475, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001032210-02-001351_insights.json
# Extracted - Year: 2023, Revenue: 111.6, Net Income: 111.6, Tax Rate: 15.5, Foreign Income: 72.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001032210-00-001961_insights.json
# Extracted - Year: 2022, Revenue: 3.5, Net Income: 300.0, Tax Rate: 12.5, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-14-289961_insights.json
# Extracted - Year: 2021, Revenue: 46.39, Net Income: 9.86, Tax Rate: 12.8, Foreign Income: 89.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-04-150689_insights.json
# Extracted - Year: 2020, Revenue: 46.656, Net Income: 10.995, Tax Rate: 10.3, Foreign Income: 85.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0000950170-23-035122_insights.json
# Extracted - Year: 2019, Revenue: 50.096, Net Income: 10.919, Tax Rate: 10.7, Foreign Income: 82.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001564590-22-026876_insights.json
# Extracted - Year: 2018, Revenue: None, Net Income: None, Tax Rate: 17.6, Foreign Income: 37.4
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-10-171791_insights.json
# Extracted - Year: 2017, Revenue: 19.5, Net Income: 2.1, Tax Rate: 10.1, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001564590-21-039151_insights.json
# Extracted - Year: 2016, Revenue: 26.438, Net Income: 7.411, Tax Rate: 9.6, Foreign Income: 90.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-16-662209_insights.json
# Extracted - Year: 2015, Revenue: 52.102, Net Income: 11.97, Tax Rate: 10.1, Foreign Income: 84.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-15-272806_insights.json
# Extracted - Year: 2014, Revenue: 31.527, Net Income: 9.768, Tax Rate: 10.7, Foreign Income: 85.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001564590-18-019062_insights.json
# Extracted - Year: 2013, Revenue: 89.0, Net Income: 11.9, Tax Rate: 9.9, Foreign Income: 85.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-03-045632_insights.json
# Extracted - Year: 2012, Revenue: 284.278, Net Income: 4.983, Tax Rate: 12.9, Foreign Income: 81.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-06-180008_insights.json
# Extracted - Year: 2011, Revenue: None, Net Income: None, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-13-310206_insights.json
# Extracted - Year: 2010, Revenue: 72.415, Net Income: 19.904, Tax Rate: 10.3, Foreign Income: 82.7
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001564590-17-014900_insights.json
# Extracted - Year: 2009, Revenue: 38.656, Net Income: 10.096, Tax Rate: 9.9, Foreign Income: 85.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0000891020-96-001130_insights.json
# Extracted - Year: 2008, Revenue: 810.545, Net Income: 170.078, Tax Rate: 15.4, Foreign Income: 71.33
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001564590-20-034944_insights.json
# Extracted - Year: 2007, Revenue: 11.4, Net Income: 3.1, Tax Rate: 9.9, Foreign Income: 85.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-12-316848_insights.json
# Extracted - Year: 2006, Revenue: 26.08, Net Income: 4.44, Tax Rate: 14.5, Foreign Income: 70.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001032210-98-001067_insights.json
# Extracted - Year: 2005, Revenue: 17.0, Net Income: 5.2, Tax Rate: 9.95, Foreign Income: 83.75
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001032210-99-001375_insights.json
# Extracted - Year: 2004, Revenue: 51.656, Net Income: 10.358, Tax Rate: 9.9, Foreign Income: 83.75
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-11-200680_insights.json
# Extracted - Year: 2003, Revenue: 870.0, Net Income: 36.0, Tax Rate: 12.5, Foreign Income: 17.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-09-158735_insights.json
# Extracted - Year: 2002, Revenue: None, Net Income: None, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-07-170817_insights.json
# Extracted - Year: 2001, Revenue: 3.5, Net Income: 350.0, Tax Rate: 9.0, Foreign Income: 77.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-05-174825_insights.json
# Extracted - Year: 2000, Revenue: 190.34, Net Income: 18.12, Tax Rate: 9.35, Foreign Income: 82.5
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001564590-19-027952_insights.json
# Extracted - Year: 1999, Revenue: 16.09, Net Income: 6.52, Tax Rate: 13.5, Foreign Income: 55.0
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001017062-97-001764_insights.json
# Extracted - Year: 1998, Revenue: 0.0, Net Income: 0.0, Tax Rate: None, Foreign Income: None
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0000891020-95-000433_insights.json
# Extracted - Year: 1997, Revenue: 75.749, Net Income: 17.749, Tax Rate: None, Foreign Income: 82.7
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001032210-01-501099_insights.json
# Extracted - Year: 1996, Revenue: 270.0, Net Income: 31.0, Tax Rate: 17.67, Foreign Income: 12.33
# Processing /Users/adi_shukla/Documents/sec-edgar-proj/insights/MSFT/0001193125-08-162768_insights.json
# Extracted - Year: 1995, Revenue: None, Net Income: 50.0, Tax Rate: 15.4, Foreign Income: 65.0
# Completed processing the specified JSON files.

# %%
def create_written_insights(company_folder):
    """
    Extracts insights from the 10-K filings of a company by reading all submission.txt files.

    Args:
    - company_folder (str): Path to the folder containing the company's 10-K filings.

    Returns:
    - tuple: A tuple containing the company name (str) and the concatenated text of all 10-K filings (str).
    """
    report_text = ""
    for submission_folder in os.listdir(company_folder):
        submission_folder_path = os.path.join(company_folder, submission_folder)
        if os.path.isdir(submission_folder_path):
            submission_file_path = os.path.join(submission_folder_path, 'submission.txt')
            if os.path.exists(submission_file_path):
                with open(submission_file_path, 'r') as file:
                    submission_text = file.read()
                    report_text += submission_text + "\n"
                    print(f"Read report from: {submission_file_path}\n{submission_text}")  # Debug statement

    company_name = os.path.basename(company_folder)
    return company_name, report_text

def summarize_company_findings(company_folder):
    """
    Analyzes a company's 10-K filings to extract insights using OpenAI's API.

    Args:
    - company_folder (str): Path to the folder containing the company's 10-K filings.

    Returns:
    - tuple: A tuple containing the company name (str) and the extracted insights (str).
    """
    company_name, report_text = create_written_insights(company_folder)
    
    prompt = f"""
    You are an analyst examining {company_name}'s 10-K filings. Extract the following insights:
    1. Revenue and Net Income trends/growth percentage.
    2. Total Debt.
    3. Gross Margin and Percentage.
    4. Capital Expenditure.
    5. Effective Tax Rate and Deferred Tax Assets/Liabilities.
    6. Number of Shares Outstanding.
    7. Foreign Income Percentage.
    8. Share Buy-Back.
    And then give two more custom insights which you deem as important.
    
    Make sure that the insights are for the specific company.
    
    Here are the reports:
    {report_text}
    
    Provide the insights in a structured format.
    """
    
    try:
        response = openai.Completion.create(
            model="gpt-3.5-turbo-instruct",
            prompt=prompt,
            max_tokens=1500,
            n=1,
            stop=None,
            temperature=0.7,
        )
        return company_name, response['choices'][0]['text'].strip()
    except Exception as e:
        print(f"Error extracting insights: {e}")  # Debug statement
        return company_name, ""

sub_folder = '/Users/adi_shukla/Documents/sec-edgar-proj/sec-edgar-filings'
companies = ['AAPL', 'MSFT', 'TSLA']
all_insights = []

# Iterate over each company
for company in companies:
    company_folder = os.path.join(sub_folder, company, '10-K')
    print(f"Analyzing reports for {company} in folder: {company_folder}\n")
    # Analyze the company's 10-K filings and extract insights
    company_name, insights = summarize_company_findings(company_folder)
    if insights:
        # Append the company name and its insights to the list
        all_insights.append({
            "Company": company_name,
            "Insights": insights
        })
        print(f"Company: {company_name}")
        print(f"Insights:\n{insights}\n")
        print("-" * 80)
    else:
        print(f"No insights found for {company_name}.\n")

print("Analysis completed.")
# Out:
# Analyzing reports for AAPL in folder: /Users/adi_shukla/Documents/sec-edgar-proj/sec-edgar-filings/AAPL/10-K
#
# Company: 10-K
# Insights:
# 1. Revenue and Net Income Trends/Growth Percentage:
# - The company has shown consistent growth in both its revenue and net income over the past five years, with an average annual growth rate of 5% and 8% respectively.
# - In the most recent year, the company's revenue increased by 7% and its net income increased by 10% compared to the previous year.
# - This growth can be attributed to the company's successful product innovations and expansion into new markets.
#
# 2. Total Debt:
# - The company's total debt has been decreasing over the past five years, with a significant decrease of 20% in the most recent year.
# - This decrease can be attributed to the company's focus on debt reduction and improved financial management.
# - As a result, the company's debt-to-equity ratio has also decreased, indicating a stronger financial position.
#
# 3. Gross Margin and Percentage:
# - The company's gross margin has remained relatively stable over the past five years, with an average of 40%.
# - In the most recent year, the company's gross margin increased by 2%, reaching a total of 42%.
# - This increase can be attributed to the company's cost-cutting initiatives and improved operational efficiency.
#
# 4. Capital Expenditure:
# - The company's capital expenditure has increased by 10% in the most recent year, reaching a total of $500 million.
# - This increase can be attributed to the company's investments in new technology and equipment to support its growth strategy.
# - The company's capital expenditure has been consistently increasing over the past five years, indicating its commitment to long-term growth.
#
# 5. Effective Tax Rate and Deferred Tax Assets/Liabilities:
# - The company's effective tax rate has decreased from 25% to 20% over the past five years, due to tax incentives and deductions.
# - The company also has a significant amount of deferred tax assets, which can be used to offset future tax liabilities.
# - This indicates that the company has a solid tax planning strategy in place to minimize its tax payments and maximize its profitability.
#
# 6. Number of Shares Outstanding:
# - The company has consistently bought back its shares over the past five years, resulting in a decrease in the number of shares outstanding by 15%.
# - This indicates that the company is confident in its financial performance and is returning value to its shareholders through share buybacks.
# - In the most recent year, the company bought back an additional 5% of its shares, further reducing the number of shares outstanding.
#
# 7. Foreign Income Percentage:
# - The company generates 30% of its total income from foreign markets.
# - This indicates that the company has a significant global presence and is not overly dependent on a single market for its revenue.
# - The company's foreign income percentage has been consistently increasing over the past five years, indicating its successful expansion into new markets.
#
# 8. Share Buy-Back:
# - The company's share buyback program has been very successful, with a total of $1 billion spent on repurchasing shares over the past five years.
# - This has resulted in a significant increase in earnings per share, as the company's net income is now divided among a smaller number of shares.
# - The company has also consistently increased its dividend payments to shareholders, indicating its commitment to returning value to its shareholders.
#
# 9. Return on Equity:
# - The company's return on equity (ROE) has consistently been above the industry average, averaging at 20% over the past five years.
# - This indicates that the company is generating strong returns for its shareholders and effectively utilizing its equity to generate profits.
# - In the most recent year, the company's ROE increased to 25%, indicating its continued success in generating shareholder value.
#
# 10. Research and Development (R&D) Expenditure:
# - The company's R&D expenditure has consistently increased over the past five years, reaching a total of $300 million in the most recent year.
# - This indicates the company's commitment to innovation and developing new products to stay competitive in the market.
# - The company's R&D efforts have resulted in successful product launches and have contributed to its revenue growth in recent years.
#
# --------------------------------------------------------------------------------
# Analyzing reports for MSFT in folder: /Users/adi_shukla/Documents/sec-edgar-proj/sec-edgar-filings/MSFT/10-K
#
# Company: 10-K
# Insights:
# Company Name: XYZ Corporation
#
# 1. Revenue and Net Income trends/growth percentage:
#     - From 2016 to 2020, XYZ Corporation's revenue has steadily increased by an average of 8% per year.
#     - The company's net income has also shown consistent growth, with an average annual growth rate of 10% over the same period.
#     - This indicates that XYZ Corporation has been able to effectively manage its operations and increase profitability over the past five years.
#
# 2. Total Debt:
#     - As of the latest 10-K filing, XYZ Corporation's total debt stands at $500 million.
#     - This is a 25% increase from the previous year, indicating that the company has taken on additional debt to fund its operations or expansion.
#     - However, the company's debt-to-equity ratio remains relatively low at 0.5, indicating that XYZ Corporation has a strong balance sheet and is not heavily burdened by debt.
#
# 3. Gross Margin and Percentage:
#     - XYZ Corporation's gross margin has remained relatively stable over the past five years, averaging at 40%.
#     - This indicates that the company has been able to maintain a healthy level of profitability after accounting for the cost of goods sold.
#     - The gross margin percentage has also remained consistent at around 35%, showing that the company has been able to effectively manage its production costs.
#
# 4. Capital Expenditure:
#     - In the latest 10-K filing, XYZ Corporation reported a total capital expenditure of $100 million.
#     - This is a 10% increase from the previous year, indicating that the company has been investing in its operations or expanding into new markets.
#     - This level of capital expenditure suggests that XYZ Corporation is committed to long-term growth and is willing to invest in its future.
#
# 5. Effective Tax Rate and Deferred Tax Assets/Liabilities:
#     - XYZ Corporation's effective tax rate for the past year was 25%, which is in line with the statutory corporate tax rate.
#     - The company also reported $50 million in deferred tax assets and $75 million in deferred tax liabilities.
#     - This suggests that XYZ Corporation has utilized tax planning strategies to minimize its tax liability and has a manageable level of deferred tax assets and liabilities.
#
# 6. Number of Shares Outstanding:
#     - As of the latest 10-K filing, XYZ Corporation had 100 million shares outstanding.
#     - This has remained consistent over the past five years, indicating that the company has not engaged in any significant share issuances or buybacks.
#
# 7. Foreign Income Percentage:
#     - XYZ Corporation generated 20% of its total revenue from foreign markets in the past year.
#     - This indicates that the company has a relatively small exposure to international markets, which may pose risks in terms of currency fluctuations and geopolitical events.
#
# 8. Share Buy-Back:
#     - In the previous year, XYZ Corporation bought back $50 million worth of its own shares.
#     - This suggests that the company has confidence in its financial position and is returning value to shareholders through share repurchases.
#
# 9. Inventory Turnover:
#     - XYZ Corporation's inventory turnover ratio has been consistently high at 10 over the past five years.
#     - This indicates that the company has been able to efficiently manage its inventory and convert it into sales.
#
# 10. Return on Equity:
#     - XYZ Corporation's return on equity (ROE) has been steadily increasing over the past five years, reaching 15% in the latest filing.
#     - This indicates that the company has been able to generate a higher return for its shareholders' investments.
#
# --------------------------------------------------------------------------------
# Analyzing reports for TSLA in folder: /Users/adi_shukla/Documents/sec-edgar-proj/sec-edgar-filings/TSLA/10-K
#
# Company: 10-K
# Insights:
# Company Name: XYZ Corporation
#
# 1. Revenue and Net Income trends/growth percentage:
#     - In the past five years, XYZ Corporation's revenue has grown at an average rate of 8%, from $1 billion in 2015 to $1.4 billion in 2019.
#     - Net income has also shown consistent growth, with an average annual growth rate of 10% over the same period.
#     - This indicates that the company has been able to effectively increase its revenue while maintaining profitability.
#
# 2. Total Debt:
#     - As of 2019, XYZ Corporation's total debt stands at $500 million.
#     - This represents a 20% increase from the previous year, where the company had a total debt of $400 million.
#     - It is important to note that the company's debt has been increasing at a faster rate than its revenue, which could potentially impact its financial stability.
#
# 3. Gross Margin and Percentage:
#     - XYZ Corporation's gross margin has remained steady at around 35% over the past five years.
#     - This indicates that the company has been able to maintain a healthy balance between its revenue and cost of goods sold.
#     - In 2019, the gross margin percentage was 36%, which is slightly higher than the industry average of 33%.
#
# 4. Capital Expenditure:
#     - In 2019, XYZ Corporation's capital expenditure was $200 million.
#     - This was a significant increase from the previous year's capital expenditure of $150 million.
#     - This could indicate that the company is investing in new projects or expanding its operations.
#
# 5. Effective Tax Rate and Deferred Tax Assets/Liabilities:
#     - XYZ Corporation's effective tax rate has been around 25% in the past five years.
#     - This is in line with the industry average.
#     - The company also has a significant amount of deferred tax assets, which indicates that it may have been able to lower its taxable income through deductions and credits.
#
# 6. Number of Shares Outstanding:
#     - As of 2019, XYZ Corporation had 100 million shares outstanding.
#     - This has remained consistent over the past five years, indicating that the company has not issued any new shares or conducted any stock splits.
#
# 7. Foreign Income Percentage:
#     - XYZ Corporation generates 20% of its revenue from foreign operations.
#     - This indicates that the company has a global presence and is not solely reliant on the domestic market.
#
# 8. Share Buy-Back:
#     - In 2019, XYZ Corporation bought back 5 million shares at a cost of $50 million.
#     - This indicates that the company has confidence in its future performance and is returning value to shareholders.
#
# 9. Return on Equity:
#     - XYZ Corporation's return on equity has been consistently above the industry average of 15% in the past five years.
#     - This indicates that the company is utilizing its shareholders' investments efficiently to generate profits.
#
# 10. Earnings per Share (EPS):
#     - In the past five years, XYZ Corporation's EPS has shown an average annual growth rate of 12%.
#     - This indicates that the company is generating higher profits for its shareholders.
#
# --------------------------------------------------------------------------------
# Analysis completed.
